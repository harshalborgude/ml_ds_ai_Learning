# %% [markdown]
# # Loss Function V/S Cost Function

# %% [markdown]
# ### Loss Function :
# - In loss function we are taking diff between y and Yhat square so between only 2 points
# ## MSE = sq( Y - Y hat )
#
# ### Cost Function :
# - In cost function we are considering difference between all points sumation
# ## MSE = 1/n * Sumation(i=1 to n)* sq( Yi - Yi hat )

# %% [markdown]
# ![image.png](attachment:image.png)
