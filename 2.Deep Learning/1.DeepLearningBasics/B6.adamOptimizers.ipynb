# %% [markdown]
# ## Adam Optimizers

# %% [markdown]
# ### Advantages :
# - Adam optimizers is a combination of SGD with Momentum where it have less noise and RMSProp which have dynamic learning rate & smoothening them

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
