# %% [markdown]
# ## Weight Initialization Techniques :

# %% [markdown]
# ### 1) Uniform Distribution
# ### 2) Xavier / Glorot Initialization
# - Xavier Normal Initialization
# - Xavier Uniform Initialization
# ### 3) Kaiming He Initialization
# - He Nomrmal
# - He Uniform
#
#
# ## Key POints :
# - 1) weights should be small
# - 2) weights should not be same
# - 3) Weights should have good variance

# %% [markdown]
# ## 1) Uniform Distribution :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Xavier / Glorot Initialization :

# %% [markdown]
# ### A) Xavier Normal Initialization :
#
# - In normal distribution, all weights are initialized where mean is 0 and standard deviation is Sigma
# #### Sigma = sqrt(2 / (input + output))
#
# ### B) Xavier Uniform Initialization :
#
# - Weights will be initialized from a uniform distribution.
# #### where Min = -sqrt(6)/sqrt(input + output) ,
# #### Max = sqrt(6)/sqrt(input + output)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Kaiming He Initialization :

# %% [markdown]
# ### A) He Nomrmal :
# - All the weights will be taken using normal distribution where mean is 0 and standard deviation is sigma
# #### Where , Sigma = sqrt(2 / input)
#
# ### B) He Uniform :
# - ALl the weights will be initialized from a uniform distribution.
# #### where Min = -sqrt(6/input) ,
# #### Max = sqrt(6/input)
#
# ![image.png](attachment:image.png)
