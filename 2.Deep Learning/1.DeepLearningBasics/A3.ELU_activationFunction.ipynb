# %% [markdown]
# # ELU Activation Function (Exponential Linear Unit)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Advantages :
# ### 1) No Dead Relu Issues
# ### 2) Zero Centric
#
# ## Disadvantages :
# ### 1) Slightly more computationally intensive compare to other activation functions
