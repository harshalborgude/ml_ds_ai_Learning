# %% [markdown]
# # Back Propogation & Weight Updation

# %% [markdown]
# ### Weight Updation Formula :
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### To figure out proper weights , we have to find out global minima from gradient decent curve of weights V/S Loss
# ### we have to use above Wnew formula to calculate updated weight
# ## When slope is negative then , W new will increase
# ### W new = W old * LearningRate  (-ve)
# ### so , W new = W old + learningRate (+Ve)
#
# ## When Slope is possitve then , W new will reduce
# ### W new = W old - learningRate (+ve)
# ### W new = W old - learningRate (+ve)
#
# ## Importance Of Learning Rate
# - Every time weighths will be updated by learning rate
# - So learning rate decides step size towards global minima to converge
# - If we choose large learning rate / step size , then it may jump between different points and may never converge to global minima
# - so better to get learning rate as low as 0.001
#
# ### When W raches gloabl minima then , W new = W old where we have global minima
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
