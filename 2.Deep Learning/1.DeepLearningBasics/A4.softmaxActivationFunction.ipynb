# %% [markdown]
# ## softmax Activation Function
# ### Used for multiclass classification problem

# %% [markdown]
# ### 1) Wherever output possibilities are more and have multiple neurons at output there sigmoid activation function cant be used , there we have to use "softmax activation function"

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### So in above example every neuron providing us some values for perticular animal
# ### neurons output we have to provide in softmax activation function
# ## E power of value / E power of all values of neuron
# - so probability of perticular animal can be found by diving softmax output with all other values and multiplying by 100
# - so above probability of horse is 86%
