# %% [markdown]
# ## Sigmoid Activation Function :

# %% [markdown]
# ###  The function output should be centered around 0 , which will increase efficiency of weight update
#
# ## Disadvantages :
#
# ### 1) exponential operation of sigmoid activation function is slower for computers , i.e
# ## sigma(X) = 1 / (1+pov(e) of -x)
# ### 2) Prone to gradient vanishing
#
#
# ## Advantages :
# ### 1) smooth gradient , preventing jumps in output value
# ### 2) output values bound between 0 to 1 , normalizes output of each neuron
# ### 3) clear prediction , i.e very close to 1 or 0
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6.59
