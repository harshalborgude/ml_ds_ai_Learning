# %% [markdown]
# # SGD with Momentum

# %% [markdown]
# ### we will apply exponential weighted average for every time we update the weights , which will smothen out the noise .
# - Here Beta will always be in between 0 to 1 & will multiply,
# ### point 3 value = Beta * point 1 value + (1 - Beta) * point 2 value
#
#
# ## Advantages :
# - 1) reduces the noise
# - 2) Leads to quick convergence
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
