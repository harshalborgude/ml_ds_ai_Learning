# %% [markdown]
# # Chain Rule Of Derivatives

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Chain Rule Of Derivatives
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Assignment To Find Out Chain Rule Formula :
#
# ![image.png](attachment:image.png)
#
# ### Answer :
#
# ![image-2.png](attachment:image-2.png)
